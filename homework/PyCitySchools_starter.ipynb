# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\$645-675) underperformed compared to schools with smaller budgets (<\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "../resources/schools_complete 2.csv"
student_data_to_load = "../resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
schools_df = pd.read_csv(school_data_to_load)
students_df = pd.read_csv(student_data_to_load)


# Combine the data into a single dataset
merged_df = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# get list of unique school names
unique_school_names = schools_df['school_name'].unique()

# get count of unique school names
school_count = len(unique_school_names)

# total students
total_students = schools_df['size'].sum()
                                                                                                   
# total budget
total_budget = schools_df['budget'].sum()

# students whose reading score is equal than or greater to 70 and percentage of student passing the reading test.
num_pass_read = students_df.loc[students_df['reading_score'] >= 70]['reading_score'].count()
perc_pass_read = num_pass_read/total_students

# students whose math score is equal than or greater to 70 and percentage of student passing the math test.
num_pass_math = students_df.loc[students_df['math_score'] >= 70]['math_score'].count()
perc_pass_math = num_pass_math/total_students

#Average math score for the students
avg_math_score = students_df['math_score'].mean()

#Average reaDING score for the students
avg_read_score = students_df['reading_score']

#Overall pass score. In other words, student passing both math and reading test
overall_pass = students_df[(students_df['math_score'] >= 70) & (students_df['reading_score'] >= 70)]['school_name'].count()

# district dataframe from dictionary

district_summary = pd.DataFrame({

    "Total Schools": [school_count],
    "Total Students": [total_students],
    "Total Budget": [total_budget],
    "Average Reading Score": [avg_read_score],
    "Average Math Score": [avg_math_score],
    "% Passing Reading": [perc_pass_read],
    "% Passing Math": [perc_pass_math],
    "Overall Passing Rate": [overall_pass]

})

# store as different df to change order
dist_sum = district_summary[["Total Schools",
                             "Total Students",
                             "Total Budget",
                             "Average Reading Score",
                             "Average Math Score",
                             '% Passing Reading',
                             '% Passing Math',
                             'Overall Passing Rate']]

dist_sum
# Out:
#    Total Schools  Total Students  Total Budget  \
# 0             15           39170      24649428
#
#                                Average Reading Score  Average Math Score  \
# 0  0        66
# 1        94
# 2        90
# 3        6...           78.985371
#
#    % Passing Reading  % Passing Math  Overall Passing Rate
# 0           0.858055        0.749809                 25528

# %%
#* Create an overview table that summarizes key metrics about each school, including:
#* School Name
#* School Type
# * Total Students
# * Total School Budget
# * Per Student Budget
#* Average Math Score
#* Average Reading Score
#* % Passing Math
#* % Passing Reading
#* Overall Passing Rate (Average of the above two)
  
#* Create a dataframe to hold the above results

# %%
#Creating a variable that uses the merged csv files  that uses school_name as index to group by
by_school = merged_df.set_index('school_name').groupby(['school_name'])
by_school

#Creating a variable that uses the merged csv files that uses school_name as index and groups by type
school_types = schools_df.set_index('school_name')['type']

#Count of students per school
stu_per_sch = by_school['Student ID'].count()

#Total budget per school
sch_budget = schools_df.set_index('school_name')['budget']/schools_df.set_index('school_name')['size']

#Total budget per student
stu_budget = schools_df.set_index('school_name')['budget']/schools_df.set_index('school_name')['size']

#Average math school by school
avg_math = by_school['math_score'].mean()

#Avergae reading score by school
avg_read = by_school['reading_score'].mean()

#Passing math score per school
pass_math = merged_df[merged_df['math_score'] >= 70].groupby('school_name')['Student ID'].count()/stu_per_sch 

#Passing reading score per score
pass_read = merged_df[merged_df['reading_score'] >= 70].groupby('school_name')['Student ID'].count()/stu_per_sch 

#Overall passing score per school
overall = merged_df[(merged_df['reading_score'] >= 70) & (merged_df['math_score'] >= 70)].groupby('school_name')['Student ID'].count()/stu_per_sch 

#Creating a data frame using above specified parameters
sch_summary = pd.DataFrame({
    "School Type": school_types,
    "Total Students": stu_per_sch,
    "Per Student Budget": stu_budget,
    "Total School Budget": sch_budget,
    "Average Math Score": avg_math,
    "Average Reading Score": avg_read,
    '% Passing Math': pass_math,
    '% Passing Reading': pass_read,
    "Overall Passing Rate": overall
})

sch_summary
# Out:
#                       School Type  Total Students  Per Student Budget  \
# Bailey High School       District            4976               628.0
# Cabrera High School       Charter            1858               582.0
# Figueroa High School     District            2949               639.0
# Ford High School         District            2739               644.0
# Griffin High School       Charter            1468               625.0
# Hernandez High School    District            4635               652.0
# Holden High School        Charter             427               581.0
# Huang High School        District            2917               655.0
# Johnson High School      District            4761               650.0
# Pena High School          Charter             962               609.0
# Rodriguez High School    District            3999               637.0
# Shelton High School       Charter            1761               600.0
# ...

# %% [markdown]
# ## School Summary

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
#Values for top 5 performing schools
top_5 = sch_summary.sort_values("Overall Passing Rate", ascending = False)
top_5.head()
# Out:
#                     School Type  Total Students  Per Student Budget  \
# Cabrera High School     Charter            1858               582.0
# Thomas High School      Charter            1635               638.0
# Griffin High School     Charter            1468               625.0
# Wilson High School      Charter            2283               578.0
# Pena High School        Charter             962               609.0
#
#                      Total School Budget  Average Math Score  \
# Cabrera High School                582.0           83.061895
# Thomas High School                 638.0           83.418349
# Griffin High School                625.0           83.351499
# Wilson High School                 578.0           83.274201
# Pena High School                   609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780        0.941335           0.970398
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
#Values for bottom 5 performing schools
bot_5 = sch_summary.sort_values("Overall Passing Rate", ascending = True)
bot_5.head()
# Out:
#                       School Type  Total Students  Per Student Budget  \
# Rodriguez High School    District            3999               637.0
# Figueroa High School     District            2949               639.0
# Huang High School        District            2917               655.0
# Hernandez High School    District            4635               652.0
# Johnson High School      District            4761               650.0
#
#                        Total School Budget  Average Math Score  \
# Rodriguez High School                637.0           76.842711
# Figueroa High School                 639.0           76.711767
# Huang High School                    655.0           76.629414
# Hernandez High School                652.0           77.289752
# Johnson High School                  650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686        0.663666
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#Average math score for students in grade 9, 10,11 and 12.
ninth = students_df.loc[students_df['grade'] == '9th'].groupby('school_name')['math_score'].mean()
tenth = students_df.loc[students_df['grade'] == '10th'].groupby('school_name')['math_score'].mean()
eleventh = students_df.loc[students_df['grade'] == '11th'].groupby('school_name')['math_score'].mean()
twelfth = students_df.loc[students_df['grade'] == '12th'].groupby('school_name')['math_score'].mean()
math_scores = pd.DataFrame({
        "9th": ninth,
        "10th": tenth,
        "11th": eleventh,
        "12th": twelfth
})
math_scores
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#Average reading score for students in grade 9, 10,11 and 12.
ninth = students_df.loc[students_df['grade'] == '9th'].groupby('school_name')['reading_score'].mean()
tenth = students_df.loc[students_df['grade'] == '10th'].groupby('school_name')['reading_score'].mean()
eleventh = students_df.loc[students_df['grade'] == '11th'].groupby('school_name')['reading_score'].mean()
twelfth = students_df.loc[students_df['grade'] == '12th'].groupby('school_name')['reading_score'].mean()
read_scores = pd.DataFrame({
        "9th": ninth,
        "10th": tenth,
        "11th": eleventh,
        "12th": twelfth
})
read_scores
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
#Uning the provided bins and grouping by the range below.Unsing cut to segment and sort data values into bins

from pandas import cut
bins = [0, 585, 615, 645, 675]
group_name = ['< $585', '$585 - 614',  '615 - 644', '> $644']
merged_df['spending_bins'] = cut(merged_df['budget']/merged_df['size'], bins, labels=group_name)
merged_df
# Out:
#        Student ID         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
by_spending = merged_df.groupby('spending_bins')
# calculations
avg_math = by_spending['math_score'].mean()
avg_read = by_spending['reading_score'].mean()
pass_math = merged_df[merged_df['math_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
pass_read = merged_df[merged_df['reading_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
overall = merged_df[(merged_df['reading_score'] >= 70) & (merged_df['math_score'] >= 70)].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()

            
# df build            
scores_by_spend = pd.DataFrame({
    "Average Math Score": avg_math,
    "Average Reading Score": avg_read,
    '% Passing Math': pass_math,
    '% Passing Reading': pass_read,
    "Overall Passing Rate": overall
            
})

scores_by_spend
# Out:
#                Average Math Score  Average Reading Score  % Passing Math  \
# spending_bins
# < $585                  83.363065              83.964039        0.937029
# $585 - 614              83.529196              83.838414        0.941241
# 615 - 644               78.061635              81.434088        0.714004
# > $644                  77.049297              81.005604        0.662308
#
#                % Passing Reading  Overall Passing Rate
# spending_bins
# < $585                  0.966866              0.906407
# $585 - 614              0.958869              0.901212
# 615 - 644               0.836148              0.602893
# > $644                  0.811094              0.535288

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
scores_by_spend.index.name = "Per Student Budget"
scores_by_spend = scores_by_spend.reindex(group_name)
scores_by_spend
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Per Student Budget
# < $585                       83.363065              83.964039        0.937029
# $585 - 614                   83.529196              83.838414        0.941241
# 615 - 644                    78.061635              81.434088        0.714004
# > $644                       77.049297              81.005604        0.662308
#
#                     % Passing Reading  Overall Passing Rate
# Per Student Budget
# < $585                       0.966866              0.906407
# $585 - 614                   0.958869              0.901212
# 615 - 644                    0.836148              0.602893
# > $644                       0.811094              0.535288

# %%
by_type = merged_df.groupby("type")

#calculations 
avg_math = by_type['math_score'].mean()
avg_read = by_type['math_score'].mean()
pass_math = merged_df[merged_df['math_score'] >= 70].groupby('type')['Student ID'].count()/by_type['Student ID'].count()
pass_read = merged_df[merged_df['reading_score'] >= 70].groupby('type')['Student ID'].count()/by_type['Student ID'].count()
overall = merged_df[(merged_df['reading_score'] >= 70) & (merged_df['math_score'] >= 70)].groupby('type')['Student ID'].count()/by_type['Student ID'].count()

# df build            
scores_by_type = pd.DataFrame({
    "Average Math Score": avg_math,
    "Average Reading Score": avg_read,
    '% Passing Math': pass_math,
    '% Passing Reading': pass_read,
    "Overall Passing Rate": overall})
    
#reorder columns
scores_by_type = scores_by_type[[
    "Average Math Score",
    "Average Reading Score",
    '% Passing Math',
    '% Passing Reading',
    "Overall Passing Rate"
]]
scores_by_type.index.name = "Type of School"
scores_by_type
# Out:
#                 Average Math Score  Average Reading Score  % Passing Math  \
# Type of School
# Charter                  83.406183              83.406183        0.937018
# District                 76.987026              76.987026        0.665184
#
#                 % Passing Reading  Overall Passing Rate
# Type of School
# Charter                  0.966459              0.905609
# District                 0.809052              0.536959
